# %%
base='https://www.yes24.com/Product/Search?query=%25ED%258C%258C%25EC%259D%25B4%25EC%258D%25AC&page='

# %%
def save_img(src,title):
    pattern=r'[가-힣a-zA-Z0-9]+'
    result=re.findall(pattern,title)
    result=' '.join(result)
    path=f'data/images/{result}.jpg'
    req.urlretrieve(src,path)
    print(path,'저장됨')

# %%
import requests
from bs4 import BeautifulSoup as bs
import re
books=[]
for i in range(1,6):
    url=base+str(i)
    res=requests.get(url)
    soup=bs(res.text,'html.parser')
    item_list=soup.select('#yesSchList > li')
    for item in item_list:
        title=item.select_one('a.gd_name').text
        author=item.select_one('span.authPub.info_auth > a').text
        price=item.select_one('div.info_row.info_price > strong > em').text.replace(',','')
        grade=item.select_one('span.rating_grade > em')
        if grade:
            grade=grade.text
        else:
            grade='0.0'
        data=(title,author,int(price),float(grade))

        img=item.select_one('img.lazy')
        src=img['data-original']
        save_img(src,title)
        #print(data) 
        books.append(data)  
print(books)
# Out:
# data/images/Do it 점프 투 파이썬.jpg 저장됨
# data/images/두근두근 파이썬.jpg 저장됨
# data/images/파이썬 for Beginner.jpg 저장됨
# data/images/혼자 공부하는 파이썬.jpg 저장됨
# data/images/난생처음 파이썬 프로그래밍.jpg 저장됨
# data/images/밑바닥부터 시작하는 딥러닝 1.jpg 저장됨
# data/images/으뜸 파이썬.jpg 저장됨
# data/images/파워 유저를 위한 파이썬 EXPRESS.jpg 저장됨
# data/images/혼자 공부하는 머신러닝 딥러닝.jpg 저장됨
# data/images/난생처음 컴퓨팅 사고 with 파이썬.jpg 저장됨
# data/images/따라하며 배우는 파이썬과 데이터 과학.jpg 저장됨
# data/images/혼자 만들면서 공부하는 파이썬.jpg 저장됨
# data/images/파이썬으로 쉽게 배우는 자료구조.jpg 저장됨
# data/images/데이터 과학을 위한 기초수학 with 파이썬.jpg 저장됨
# data/images/컴퓨팅 기반 문제해결 with 파이썬.jpg 저장됨
# data/images/새내기 파이썬.jpg 저장됨
# data/images/수학자와 함께하는 인공지능 수학 with 파이썬.jpg 저장됨
# data/images/최신 파이썬 완전정복 기초에서 심화까지.jpg 저장됨
# data/images/코딩 자율학습 나도코딩의 파이썬 입문.jpg 저장됨
# data/images/파이썬 업무 자동화 일잘러 되기 챗GPT.jpg 저장됨
# data/images/어서와 파이썬은 처음이지.jpg 저장됨
# data/images/진짜 업무에 쓰는 챗GPT 노코드 데이터 분석.jpg 저장됨
# data/images/대표 전략으로 입문하는 미국 주식 퀀트 투자.jpg 저장됨
# data/images/파이썬으로 웹 크롤러 만들기.jpg 저장됨
# data/images/야구 데이터로 배우는 파이썬.jpg 저장됨
# data/images/2025 시대에듀 빅데이터분석기사 실기 파이썬 한권으로 끝내기.jpg 저장됨
# data/images/시간순삭 파이썬.jpg 저장됨
# data/images/파이썬과 JAX로 추천 시스템 구축하기.jpg 저장됨
# data/images/데이터 과학을 위한 소프트웨어 엔지니어링.jpg 저장됨
# data/images/자료구조와 알고리즘 with 파이썬.jpg 저장됨
# data/images/파이썬으로 배우는 자료구조.jpg 저장됨
# data/images/2025 최적합 빅데이터분석기사 실기 파이썬.jpg 저장됨
# data/images/파이썬 자료구조와 알고리즘 for Beginner.jpg 저장됨
# data/images/실전 코드부터 배우는 실무 활용 파이썬 with 챗GPT.jpg 저장됨
# data/images/NLP와 LLM 실전 가이드.jpg 저장됨
# data/images/Do it 자료구조와 함께 배우는 알고리즘 입문 파이썬 편.jpg 저장됨
# data/images/파이썬 워크북.jpg 저장됨
# data/images/Streamlit 으로 프로젝트 한방에 끝내기 With 파이썬.jpg 저장됨
# data/images/마이크로 파이썬으로 만드는 스마트 자동차.jpg 저장됨
# data/images/마이크로 파이썬으로 만드는 드론과 사물인터넷.jpg 저장됨
# data/images/모두의 데이터 분석 with 파이썬.jpg 저장됨
# data/images/정말 쉽네 챗GPT 구글 업무 자동화 이게 되네 업무 자동화 미친 활용 앱스 스크립트 with 챗GPT 파이썬 업무 자동화 일잘러 되기 챗GPT 세트.jpg 저장됨
# data/images/파이썬 프로그래밍.jpg 저장됨
# data/images/친절한 파이썬 프로그래밍.jpg 저장됨
# data/images/비전공자가 배우는 파이썬.jpg 저장됨
# data/images/선생님을 위한 8282 업무 자동화 with AI 파이썬 노코드.jpg 저장됨
# data/images/2025 단 축 키 빅데이터 분석기사 실기 파이썬 작업형.jpg 저장됨
# data/images/자연어 처리를 위한 허깅페이스 트랜스포머 하드 트레이닝.jpg 저장됨
# data/images/데이터 과학 기반의 파이썬 빅데이터 분석.jpg 저장됨
# data/images/인공지능.jpg 저장됨
# data/images/코드형 인프라의 패턴과 실무.jpg 저장됨
# data/images/혼자 공부하는 데이터 분석 with 파이썬.jpg 저장됨
# data/images/Do it 점프 투 파이썬.jpg 저장됨
# data/images/파이썬으로 풀어보는 컴퓨팅 사고.jpg 저장됨
# data/images/파이썬 마스터.jpg 저장됨
# data/images/Do it 쉽게 배우는 파이썬 데이터 분석.jpg 저장됨
# data/images/데이터 과학을 위한 파이썬 프로그래밍.jpg 저장됨
# data/images/쉽게 배우는 자료구조 with 파이썬.jpg 저장됨
# data/images/난생처음 데이터 분석 with 파이썬.jpg 저장됨
# data/images/컴퓨터 비전과 딥러닝.jpg 저장됨
# data/images/창의적 문제 해결을 위한 파이썬 프로그래밍.jpg 저장됨
# data/images/컴퓨팅 사고와 파이썬.jpg 저장됨
# data/images/파이썬으로 배우는 컴퓨팅 사고.jpg 저장됨
# data/images/프로그래밍의 정석 파이썬.jpg 저장됨
# data/images/파이썬 머신러닝 완벽 가이드.jpg 저장됨
# data/images/컴퓨팅 사고와 소프트웨어 with 파이썬.jpg 저장됨
# data/images/파이썬으로 만드는 인공지능.jpg 저장됨
# data/images/AI 시대의 파이썬 데이터 분석.jpg 저장됨
# data/images/만들면서 배우는 파이썬과 40개의 작품들.jpg 저장됨
# data/images/Do it 첫 파이썬.jpg 저장됨
# data/images/알기 쉽게 해설한 파이썬 with 컴퓨팅 사고력.jpg 저장됨
# data/images/오렌지3 with 파이썬.jpg 저장됨
# data/images/혼자 공부하는 머신러닝 딥러닝.jpg 저장됨
# data/images/파이썬 코딩 도장.jpg 저장됨
# data/images/AI 시대의 이산수학 with 파이썬.jpg 저장됨
# data/images/파이썬과 함께하는 생활 속의 통계학.jpg 저장됨
# data/images/원리가 보이는 파이썬 빅데이터 분석 기초와 실습.jpg 저장됨
# data/images/파이썬과 함께하는 대학 미분적분학.jpg 저장됨
# data/images/모두의 인공지능 기초 수학.jpg 저장됨
# data/images/혼자 만들면서 공부하는 파이썬.jpg 저장됨
# data/images/파이썬 for Beginner 3판.jpg 저장됨
# data/images/비전공자를 위한 이해할 수 있는 파이썬.jpg 저장됨
# data/images/파이썬 데이터 분석 for Beginner.jpg 저장됨
# data/images/이제 시작이야 컴퓨팅 사고력으로 인공지능까지 파이썬.jpg 저장됨
# data/images/혼자 공부하는 파이썬 개정판.jpg 저장됨
# data/images/응용이 보이는 선형대수학.jpg 저장됨
# data/images/모두의 인공지능 with 파이썬.jpg 저장됨
# data/images/모두의 파이썬.jpg 저장됨
# data/images/수학자와 함께하는 인공지능 수학 with 파이썬.jpg 저장됨
# data/images/챗GPT로 만드는 주식 암호화폐 자동매매 시스템.jpg 저장됨
# data/images/프로그래밍으로 배우는 양자컴퓨팅 with 파이썬.jpg 저장됨
# data/images/누구나 쉽게 자료구조와 알고리즘 with 파이썬.jpg 저장됨
# data/images/어서와 파이썬은 처음이지.jpg 저장됨
# data/images/코딩 테스트 합격자 되기 파이썬 편.jpg 저장됨
# data/images/이것이 취업을 위한 코딩 테스트다 with 파이썬.jpg 저장됨
# data/images/파이썬으로 배우는 공업수학.jpg 저장됨
# data/images/챗GPT와 파이썬으로 주식 자동매매 앱 및 웹 투자 리포트 만들기.jpg 저장됨
# data/images/문제해결 파이썬 with 기본 수학.jpg 저장됨
# data/images/파이썬 스타트.jpg 저장됨
# data/images/컴퓨팅사고와 파이썬을 활용한 코딩기초.jpg 저장됨
# data/images/1일 1로그 100일 완성 IT 지식.jpg 저장됨
# data/images/파이썬으로 배우는 누구나 코딩.jpg 저장됨
# data/images/전문가를 위한 파이썬.jpg 저장됨
# data/images/파이썬 자료구조와 알고리즘 for Beginner.jpg 저장됨
# data/images/디딤돌 파이썬.jpg 저장됨
# data/images/Do it 알고리즘 코딩 테스트 파이썬 편.jpg 저장됨
# data/images/난생처음 컴퓨팅 사고 with 파이썬.jpg 저장됨
# data/images/나도 하는 도전 파이썬 코딩.jpg 저장됨
# data/images/제대로 배우는 파이썬.jpg 저장됨
# data/images/머신 러닝 교과서 with 파이썬 사이킷런 텐서플로.jpg 저장됨
# data/images/25가지 문제로 배우는 LLM 입문 with 파이썬.jpg 저장됨
# data/images/파이썬과 함께하는 자료구조의 이해.jpg 저장됨
# data/images/누구나 쉽게 컴퓨팅 사고 with 파이썬.jpg 저장됨
# data/images/문제해결과 컴퓨팅 사고를 위한 파이썬.jpg 저장됨
# data/images/초등 도형 파이썬으로 해볼까.jpg 저장됨
# data/images/밑바닥부터 시작하는 딥러닝 2.jpg 저장됨
# data/images/모두의 데이터 분석 with 파이썬.jpg 저장됨
# data/images/Chapra의 파이썬 수치해석.jpg 저장됨
# data/images/통계학 파이썬을 이용한 분석.jpg 저장됨
# data/images/쉽게 이해되는 파이썬 프로그래밍.jpg 저장됨
# [('Do it! 점프 투 파이썬', '박응용', 19800, 9.8), ('두근두근 파이썬', '천인국', 25000, 5.0), ('파이썬 for Beginner', '우재남', 25000, 9.3), ('혼자 공부하는 파이썬', '윤인성', 19800, 9.5), ('난생처음 파이썬 프로그래밍', '우재남', 24000, 9.1), ('밑바닥부터 시작하는 딥러닝 1', '사이토 고키', 23400, 9.2), ('으뜸 파이썬', '박동규', 34000, 6.0), ('파워 유저를 위한 파이썬 EXPRESS', '천인국', 30000, 9.6), ('혼자 공부하는 머신러닝+딥러닝', '박해선', 23400, 9.6), ('난생처음 컴퓨팅 사고 with 파이썬', '김명호', 23000, 8.5), ('따라하며 배우는 파이썬과 데이터 과학', '천인국', 29000, 10.0), ('혼자 만들면서 공부하는 파이썬', '문현일', 23400, 9.5), ('파이썬으로 쉽게 배우는 자료구조', '최영규', 29000, 10.0), ('데이터 과학을 위한 기초수학 with 파이썬', '이병준', 23400, 10.0), ('컴퓨팅 기반 문제해결 with 파이썬', '장은실', 20000, 0.0), ('새내기 파이썬', '천인국', 30000, 10.0), ('수학자와 함께하는 인공지능 수학 with 파이썬', '김종락', 31680, 10.0), ('최신 파이썬 완전정복 : 기초에서 심화까지', '강환수', 34000, 0.0), ('코딩 자율학습 나도코딩의 파이썬 입문', '나도코딩', 21600, 9.8), ('파이썬 업무 자동화 일잘러 되기 + 챗GPT', '메이허', 32400, 0.0), ('어서와 파이썬은 처음이지!', '천인국', 33000, 0.0), ('진짜 업무에 쓰는 챗GPT 노코드 데이터 분석', '이기복', 29700, 10.0), ('대표 전략으로 입문하는 미국 주식 퀀트 투자', '이용환', 27000, 9.8), ('파이썬으로 웹 크롤러 만들기', '라이언 미첼', 25200, 0.0), ('야구 데이터로 배우는 파이썬', '사이토 아마네', 16200, 9.4), ('2025 시대에듀 빅데이터분석기사 실기(파이썬) 한권으로 끝내기', '장희선', 30600, 0.0), ('시간순삭 파이썬', '천인국', 22500, 10.0), ('파이썬과 JAX로 추천 시스템 구축하기', '브라이언 비쇼프', 29700, 0.0), ('데이터 과학을 위한 소프트웨어 엔지니어링', '캐서린 넬슨', 26100, 10.0), ('자료구조와 알고리즘 with 파이썬', '최영규', 21600, 9.9), ('파이썬으로 배우는 자료구조', '유석종', 29100, 0.0), ('2025 최적합 빅데이터분석기사 실기 (파이썬)', '김민지', 27000, 10.0), ('파이썬 자료구조와 알고리즘 for Beginner', '우재남', 27000, 9.3), ('실전 코드부터 배우는 실무 활용 파이썬 with 챗GPT', '박찬의', 19800, 0.0), ('NLP와 LLM 실전 가이드', '리오르 가지트', 30600, 0.0), ('Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편', '시바타 보요', 19800, 9.2), ('파이썬 워크북', '안기수', 15000, 0.0), ('Streamlit 으로 프로젝트 한방에 끝내기 With 파이썬', 'Sara', 60700, 0.0), ('마이크로 파이썬으로 만드는 스마트 자동차', '장문철', 19800, 10.0), ('마이크로 파이썬으로 만드는 드론과 사물인터넷', '장문철', 19800, 10.0), ('모두의 데이터 분석 with 파이썬', '송석리', 16200, 9.5), ('정말 쉽네? 챗GPT 구글 업무 자동화 + 이게 되네? 업무 자동화 미친 활용 앱스 스크립트 with 챗GPT + 파이썬 업무 자동화 일잘러 되기 + 챗GPT 세트', '서휘승', 82800, 10.0), ('파이썬 프로그래밍', '허준', 22500, 0.0), ('친절한 파이썬 프로그래밍', '서정만', 25200, 0.0), ('비전공자가 배우는 파이썬', '이성만', 27700, 0.0), ('선생님을 위한 8282 업무 자동화 with AI+파이썬+노코드', '강우혁', 25200, 0.0), ('2025 단·축·키 빅데이터 분석기사 실기(파이썬 작업형)', '김계철', 27000, 0.0), ('자연어 처리를 위한 허깅페이스 트랜스포머 하드 트레이닝', '박성환', 24750, 9.9), ('데이터 과학 기반의 파이썬 빅데이터 분석', '이지영', 31000, 0.0), ('인공지능', '천인국', 33000, 0.0), ('코드형 인프라의 패턴과 실무', '로즈마리 왕', 36000, 0.0), ('혼자 공부하는 데이터 분석 with 파이썬', '박해선', 23400, 9.8), ('Do it! 점프 투 파이썬', '박응용', 15000, 9.8), ('파이썬으로 풀어보는 컴퓨팅 사고', '김성애', 23000, 0.0), ('파이썬 마스터', '김종훈', 32000, 0.0), ('Do it! 쉽게 배우는 파이썬 데이터 분석', '김영우', 20700, 9.9), ('데이터 과학을 위한 파이썬 프로그래밍', '최성철', 30000, 9.0), ('쉽게 배우는 자료구조 with 파이썬', '문병로', 29000, 9.3), ('난생처음 데이터 분석 with 파이썬', '김규석', 26000, 10.0), ('컴퓨터 비전과 딥러닝', '오일석', 38610, 9.8), ('창의적 문제 해결을 위한 파이썬 프로그래밍', '김진일', 23000, 10.0), ('컴퓨팅 사고와 파이썬', '김지연', 24000, 10.0), ('파이썬으로 배우는 컴퓨팅 사고', '김완섭', 17000, 9.0), ('프로그래밍의 정석 : 파이썬', '도경구', 25200, 9.6), ('파이썬 머신러닝 완벽 가이드', '권철민', 36000, 8.9), ('컴퓨팅 사고와 소프트웨어 with 파이썬', '성태응', 25000, 0.0), ('파이썬으로 만드는 인공지능', '오일석', 31000, 8.0), ('AI 시대의 파이썬 데이터 분석', '오세종', 32000, 0.0), ('만들면서 배우는 파이썬과 40개의 작품들', '장문철', 16920, 8.9), ('Do it! 첫 파이썬', '엘리스 코딩', 12600, 9.8), ('알기 쉽게 해설한 파이썬 with 컴퓨팅 사고력', '김충석', 24000, 0.0), ('오렌지3 with 파이썬', '김현철', 27000, 10.0), ('혼자 공부하는 머신러닝+딥러닝', '박해선', 20800, 9.6), ('파이썬 코딩 도장', '남재윤', 27000, 9.8), ('AI 시대의 이산수학 with 파이썬', '박두순', 29000, 0.0), ('파이썬과 함께하는 생활 속의 통계학', '안기수', 23000, 0.0), ('원리가 보이는 파이썬 빅데이터 분석 기초와 실습', '천세학', 28000, 2.0), ('파이썬과 함께하는 대학 미분적분학', '이정례', 25000, 0.0), ('모두의 인공지능 기초 수학', '서지영', 22500, 7.6), ('혼자 만들면서 공부하는 파이썬', '문현일', 20800, 9.5), ('파이썬 for Beginner 3판', '우재남', 25000, 9.3), ('비전공자를 위한 이해할 수 있는 파이썬', '최원영', 22320, 9.3), ('파이썬 데이터 분석 for Beginner', '우재남', 28000, 2.0), ('이제 시작이야! 컴퓨팅 사고력으로 인공지능까지 파이썬', '전수진', 23000, 9.0), ('혼자 공부하는 파이썬 (개정판)', '윤인성', 17600, 9.5), ('응용이 보이는 선형대수학', '이건명', 31000, 10.0), ('모두의 인공지능 with 파이썬', '이영호', 19800, 10.0), ('모두의 파이썬', '이승찬', 10800, 9.6), ('수학자와 함께하는 인공지능 수학 with 파이썬', '김종락', 32000, 1 ...

# %%
import urllib.request as req
src= 'https://image.yes24.com/goods/107904746/L'
path= "data/images/img.jpg"
req.urlretrieve(src, path)
# Out:
# ('data/images/img.jpg', <http.client.HTTPMessage at 0x122efd860c0>)
