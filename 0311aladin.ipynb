# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import re
import urllib.request as ureq
import pymysql


def save_img(src, title):
    pattern = r'[가-힣a-zA-z0-9]+'
    result = re.findall(pattern, title)
    str = " ".join(result)
    path = f"data/images/{str}.jpg"
    
    ureq.urlretrieve(src, path)
    print(path, "저장됨.")


# 튜플 리스트 만들기
base = "https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0&page="

books = []

for i in range(3):
    url = base + str(i+1)
    res = requests.get(url)
    soup = bs(res.text, "html.parser")

    item_list = soup.select("div.ss_book_box")

    for item in item_list:
        title = item.select_one("a.bo3").text
        author = item.select_one("li:nth-child(3) > a")
        if author != None:
            author = author.text
        else:
            author = item.select_one("li:nth-child(2) > a").text
        price = int(item.select_one("li:nth-child(4) > span").text.replace(",", ""))
        if item.select_one("img.front_cover") != None:
            img = item.select_one("img.front_cover")["src"]
        else: img = None
        
        books.append((title, author, price, img))
        if img != None: save_img(img, title)


# 데이터프레임 생성 및 csv 저장
df = pd.DataFrame(books, columns=["제목", "저자", "가격", "이미지소스"])
df.to_csv("data/aladin.csv", encoding="utf-8")

df

# 데이터베이스 삽입
conn = pymysql.connect(
    host="localhost",
    user="yubeen",
    password="1234",
    database="pydb",
    charset="utf8"
)
c = conn.cursor()

sql = "INSERT INTO aladin_books(title, author, price, img_src) VALUES(%s, %s, %s, %s)"
c.executemany(sql, books)

conn.commit()
conn.close()
# Out:
# data/images/소년이 온다.jpg 저장됨.
# data/images/스토너.jpg 저장됨.
# data/images/그릿 Grit.jpg 저장됨.
# data/images/봄밤의 모든 것.jpg 저장됨.
# data/images/양심.jpg 저장됨.
# data/images/초역 부처의 말.jpg 저장됨.
# data/images/듀얼 브레인.jpg 저장됨.
# data/images/모순.jpg 저장됨.
# data/images/2025 큰별쌤 최태성의 별 별한국사 한국사능력검정시험 심화 1 2 3급 상.jpg 저장됨.
# data/images/ETS 토익 정기시험 기출문제집 1000 Vol 4 Reading 리딩.jpg 저장됨.
# data/images/황현필의 진보를 위한 역사.jpg 저장됨.
# data/images/ETS 토익 정기시험 기출문제집 1000 Vol 4 Listening 리스닝.jpg 저장됨.
# data/images/해커스 토익 기출 VOCA 보카.jpg 저장됨.
# data/images/삶이라는 완벽한 농담.jpg 저장됨.
# data/images/2025 큰별쌤 최태성의 별 별한국사 한국사능력검정시험 심화 1 2 3급 하.jpg 저장됨.
# data/images/채식주의자 리마스터판.jpg 저장됨.
# data/images/어른의 행복은 조용하다.jpg 저장됨.
# data/images/작별하지 않는다.jpg 저장됨.
# data/images/자살의 연구.jpg 저장됨.
# data/images/마음의 기술.jpg 저장됨.
# data/images/침묵의 퍼레이드.jpg 저장됨.
# data/images/급류.jpg 저장됨.
# data/images/학생회에도 구멍은 있다 8.jpg 저장됨.
# data/images/원페이지 교육학 기본서 상.jpg 저장됨.
# data/images/맨큐의 경제학.jpg 저장됨.
# data/images/환율의 대전환.jpg 저장됨.
# data/images/트럼프 시대의 지정학과 비트코인.jpg 저장됨.
# data/images/슈퍼 뒤에서 담배 피우는 두 사람 5 특장판.jpg 저장됨.
# data/images/국민이 먼저입니다.jpg 저장됨.
# data/images/스토너 초판본 양장.jpg 저장됨.
# data/images/꼭 그런 건 아니야.jpg 저장됨.
# data/images/두근두근 내 인생의 비밀 찾기 1.jpg 저장됨.
# data/images/흰 고래의 흼에 대하여.jpg 저장됨.
# data/images/그 개와 혁명.jpg 저장됨.
# data/images/이처럼 사소한 것들.jpg 저장됨.
# data/images/행동하지 않으면 인생은 바뀌지 않는다.jpg 저장됨.
# data/images/사과를 그리는 100가지 방법.jpg 저장됨.
# data/images/호랑이를 부탁해.jpg 저장됨.
# data/images/미키7.jpg 저장됨.
# data/images/이어령의 말.jpg 저장됨.
# data/images/하루 한 장 나의 어휘력을 위한 필사 노트 컴포지션 에디션.jpg 저장됨.
# data/images/쉽게 풀어쓴 C언어 Express.jpg 저장됨.
# data/images/소스 코드 더 비기닝.jpg 저장됨.
# data/images/악마와 함께 춤을.jpg 저장됨.
# data/images/2025 써니 행정법총론 실전동형 모의고사.jpg 저장됨.
# data/images/명탐정 코난 106.jpg 저장됨.
# data/images/히카루가 죽은 여름 5 특장판.jpg 저장됨.
# data/images/원페이지 교육학 기본서 하.jpg 저장됨.
# data/images/2025 이유진 국어 백일기도 모의고사 시즌 3 결.jpg 저장됨.
# data/images/나의 히어로 아카데미아 42 트리플 특장판.jpg 저장됨.
# data/images/넥서스.jpg 저장됨.
# data/images/미키7 완전판 세트 전2권.jpg 저장됨.
# data/images/나는 보았습니다.jpg 저장됨.
# data/images/ETS 토익 단기 공략 750 LC RC.jpg 저장됨.
# data/images/헌법 필사 스프링.jpg 저장됨.
# data/images/어떻게 극단적 소수가 다수를 지배하는가.jpg 저장됨.
# data/images/흰.jpg 저장됨.
# data/images/지적 대화를 위한 넓고 얕은 지식 무한.jpg 저장됨.
# data/images/교육의 뇌과학.jpg 저장됨.
# data/images/2025 이기적 빅데이터분석기사 필기 기본서.jpg 저장됨.
# data/images/일본어 명카피 핸드북.jpg 저장됨.
# data/images/2025 큰별쌤 최태성의 별 별한국사 기출 500제 한국사능력검정시험 심화 1 2 3급.jpg 저장됨.
# data/images/나의 자리.jpg 저장됨.
# data/images/심장보다 단단한 토마토 한 알.jpg 저장됨.
# data/images/느리게 가는 마음.jpg 저장됨.
# data/images/이상한 집 2.jpg 저장됨.
# data/images/착 붙는 일본어 독학 첫걸음.jpg 저장됨.
# data/images/사카모토 데이즈 19 트리플 특전판.jpg 저장됨.
# data/images/Kreyszig 공업수학 상.jpg 저장됨.
# data/images/데미안 오리지널 초판본 표지디자인.jpg 저장됨.
# data/images/도넛을 나누는 기분 시절 시집 에디션.jpg 저장됨.
# data/images/일본어 무작정 따라하기 완전판.jpg 저장됨.
# data/images/부모의 질문력.jpg 저장됨.
# data/images/소년과 두더지와 여우와 말.jpg 저장됨.
# data/images/ETS 토익기출 파트별 VOCA 보카.jpg 저장됨.
# data/images/계엄령.jpg 저장됨.
# data/images/손자병법.jpg 저장됨.
# data/images/줌달의 일반화학 Zumdahl.jpg 저장됨.
# data/images/2025 선재국어 실전 봉투 모의고사 2 결승선.jpg 저장됨.
# data/images/2025 문동균 한국사 D 30 문단속 모의고사.jpg 저장됨.
# data/images/싯다르타.jpg 저장됨.
# data/images/어른의 품격을 채우는 100일 필사 노트.jpg 저장됨.
# data/images/큼큼 산신령의 속담 상담소.jpg 저장됨.
# data/images/현대 이상심리학.jpg 저장됨.
# data/images/해커스 토익 RC Reading 리딩 기본서.jpg 저장됨.
# data/images/퓨처 셀프 30만 부 기념 스페셜 에디션.jpg 저장됨.
# data/images/대학생을 위한 자아와 명상 1.jpg 저장됨.
# data/images/2025 프로야구 가이드북.jpg 저장됨.
# data/images/이기적 유전자.jpg 저장됨.
# data/images/대학물리학.jpg 저장됨.
# data/images/설민석의 한국사 대모험 32.jpg 저장됨.
# data/images/2025 심우철 실전 동형 모의고사 Season 2.jpg 저장됨.
# data/images/2025 북적북적 저절로 암기노트 문제풀이 예금일반.jpg 저장됨.
# data/images/패턴과 구조 영문법.jpg 저장됨.
# data/images/Brown 일반화학 일반화학교재연구회.jpg 저장됨.
# data/images/히카루가 죽은 여름 5.jpg 저장됨.
# data/images/대온실 수리 보고서.jpg 저장됨.
# data/images/2025 문동균 한국사 국가직 대비 실전 봉투모의고사.jpg 저장됨.
# data/images/생각의 도약.jpg 저장됨.
# data/images/AI 시대와 언어.jpg 저장됨.
# data/images/진짜 쓰는 실무 엑셀.jpg 저장됨.
# data/images/성장지향성.jpg 저장됨.
# data/images/사랑에 대해 내가 아는 모든 것 리커버 특별판.jpg 저장됨.
# data/images/살아갈 날들을 위한 괴테의 시.jpg 저장됨.
# data/images/데일 카네기 인간관계론 자기관리론 성공대화론 합본 무선.jpg 저장됨.
# data/images/스킵과 로퍼 10.jpg 저장됨.
# data/images/왜 그들만 부자가 되는가.jpg 저장됨.
# data/images/미분적분학.jpg 저장됨.
# data/images/서랍에 저녁을 넣어 두었다.jpg 저장됨.
# data/images/퇴마록 소장판 전권 세트 전17권 양장.jpg 저장됨.
# data/images/희망.jpg 저장됨.
# data/images/2025 이동기 영어 신경향 실전동형 모의고사 Vol 2.jpg 저장됨.
# data/images/김재우의 기초 영어회화 100.jpg 저장됨.
# data/images/ALL NEW 계리직 영어 예상문제집 전2권.jpg 저장됨.
# data/images/오십의 태도.jpg 저장됨.
# data/images/2025 에듀윌 스포츠지도사 필기 한권끝장 모의고사 3회분.jpg 저장됨.
# data/images/너의 유토피아.jpg 저장됨.
# data/images/어떻게 민주주의는 무너지는가.jpg 저장됨.
# data/images/나의 작은 무법자.jpg 저장됨.
# data/images/경제학원론.jpg 저장됨.
# data/images/2025 선재국어 실전 봉투 모의고사 1 출발선.jpg 저장됨.
# data/images/두 사람의 인터내셔널.jpg 저장됨.
# data/images/돈의 심리학 30만 부 기념 스페셜 에디션.jpg 저장됨.
# data/images/ETS 토익 단기 공략 550 LC RC.jpg 저장됨.
# data/images/설민석의 삼국지 대모험 21.jpg 저장됨.
# data/images/적당한 사람.jpg 저장됨.
# data/images/티핑 포인트의 설계자들.jpg 저장됨.
# data/images/나는 AI와 공부한다.jpg 저장됨.
# data/images/생활속의 경영학.jpg 저장됨.
# data/images/현대 심리치료와 상담 이론.jpg 저장됨.
# data/images/희랍어 시간.jpg 저장됨.
# data/images/부의 공식.jpg 저장됨.
# data/images/2025 수제비 정보처리기사 실기 기본서.jpg 저장됨.
# data/images/한 권으로 끝내는 해커스 토익 700 LC RC VOCA.jpg 저장됨.
# data/images/최재천의 희망 수업.jpg 저장됨.
# data/images/트렌드 코리아 2025.jpg 저장됨.
# data/images/해커스 토익 LC Listening 리스닝 기본서.jpg 저장됨.
# data/images/4줄이면 된다.jpg 저장됨.
# data/images/내가 나라서 정말 좋아.jpg 저장됨.
# data/images/해커스 보카 Hackers Vocabulary.jpg 저장됨.
# data/images/히나타의 블루 4.jpg 저장됨.
# data/images/무의식은 어떻게 나를 설계하는가.jpg 저장됨.
# data/images/롱 뷰.jpg 저장됨.
# data/images/사회복지학개론 권중돈 외.jpg 저장됨.
# data/images/수학 진짜 잘하는 법을 알려줄게요.jpg 저장됨.
# data/images/어느 날 문이 사라졌다.jpg 저장됨.
# data/images/일의 감각.jpg 저장됨.
# data/images/캠벨 생명과학.jpg 저장됨.
